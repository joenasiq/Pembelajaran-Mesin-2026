# %% [markdown]
# <a href="https://colab.research.google.com/github/joenasiq/Pembelajaran-Mesin-2026/blob/main/TG1_244107020158_Arjuna_Satria_Hutama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tugas Praktikum 1**

# %% [markdown]
# ## **Bagian 1**

# %% [markdown]
# 1. Buat file notebook dengan nama TG1_NIM_NAMA.ipynb.
#
# 2. Lakukan instalasi library berikut pada notebook,
# - PyPREP
# - Scipy
# - wandb
# - pyECG

# %%
# !pip install pyprep scipy wandb pyecg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# 3. Jelaskan kegunakan masing-masing library tersebut.
#
# - PyPREP: untuk standarisasi preprocessing data EEG (Electroencephalography) menggunakan pipeline PREP.
# - SciPy: untuk komputasi ilmiah dalam Python yang menyediakan modul untuk optimasi, aljabar linier, integrasi, dan pengolahan sinyal.
# - wandb: untuk eksperimen machine learning yang digunakan untuk tracking metrik, visualisasi hasil model, dan kolaborasi tim.
# - pyECG: untuk ekstraksi fitur dan analisis sinyal EKG (Elektrokardiogram).

# %% [markdown]
# ## **Bagian 2**

# %% [markdown]
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
# **Pelanggaran Hak Kekayaan Intelektual**. AI generatif seperti DALL·E, MidJourney, dan Stable Diffusion mampu menciptakan ilustrasi dan animasi dengan gaya tertentu berdasarkan data pelatihan yang berasal dari berbagai karya seni yang ada di internet, sehingga memunculkan pertanyaan hukum apakah proses pelatihan tersebut melanggar hak cipta pencipta karya asli
#
# **Referensi**: JDIH Komdigi. Pelindungan Hak Cipta dalam Penggunaan AI: Studi Kasus Animasi Ghibli.

# %% [markdown]
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
# **Konsumsi air yang masif**. Pusat data mengonsumsi energi yang besar untuk pendinginan mesin, menghasilkan emisi karbon signifikan, dan metode pendinginan yang membutuhkan banyak air juga membawa dampak terhadap lingkungan. Ditambah lagi, teknologi AI turut membutuhkan konsumsi air yang begitu tinggi.
#
# **referensi:**
# - The Conversation. AI Generatif Membahayakan Lingkungan: Bagaimana Cara Mengatasinya?
# - Inilah.com. AI Bisa Sebabkan 4 Dampak Serius Ini Terhadap Lingkungan.
